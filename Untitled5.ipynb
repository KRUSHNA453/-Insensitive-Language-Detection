# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/UTKFace
# Out:
# /content/drive/MyDrive/Colab Notebooks/UTKFace

# %%
l
